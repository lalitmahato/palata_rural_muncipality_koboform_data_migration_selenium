# %%
import copy
import io
import os
import requests
import uuid
from datetime import datetime
from random import sample
from time import sleep
from typing import Tuple
from xml.etree import ElementTree as ET
import json
import pandas as pd
import pytz
import numpy as np
from PIL import Image
from io import BytesIO
import base64

# %%
old_form_df1 = pd.read_excel('aHuaFu4bdnJ36vR8TYet8x.xlsx', sheet_name='survey')
old_form_df1
# Out:
#           type                        name        label::Nepali (ne)  \
# 0        start                       start                       NaN
# 1          end                         end                       NaN
# 2         note  _span_style_color_red_span  घरमुलीको ब्यक्तिगत विवरण
# 3         text                   Full_Name                  पुरा नाम
# 4         text   Full_Name_in_Block_Letter           ब्लकमा पूरा नाम
# ..         ...                         ...                       ...
# 343  calculate               _version__001                       NaN
# 344  calculate               _version__002                       NaN
# 345  calculate               _version__003                       NaN
# 346  calculate               _version__004                       NaN
# 347  calculate               _version__005                       NaN
#
#                                    label::English (en) hint::Nepali (ne)  \
# 0                                                  NaN               NaN
# 1                                                  NaN               NaN
# 2    <span style="color:red;">1. Head of the family...               NaN
# 3                                            Full Name               NaN
# 4                            Full Name in Block Letter               NaN
# ..                                                 ...               ...
# 343                                                NaN               NaN
# 344                                                NaN               NaN
# 345                                                NaN               NaN
# 346                                                NaN               NaN
# 347                                                NaN               NaN
#
#     hint::English (en) required parameters appearance choice_filter  \
# 0                  NaN      NaN        NaN        NaN           NaN
# 1                  NaN      NaN        NaN        NaN           NaN
# 2                  NaN    False        NaN        NaN           NaN
# 3                  NaN     True        NaN        NaN           NaN
# 4                  NaN    False        NaN        NaN           NaN
# ..                 ...      ...        ...        ...           ...
# 343                NaN    False        NaN        NaN           NaN
# 344                NaN    False        NaN        NaN           NaN
# 345                NaN    False        NaN        NaN           NaN
# 346                NaN    False        NaN        NaN           NaN
# 347                NaN      NaN        NaN        NaN           NaN
#
#     constraint relevant               calculation
# 0          NaN      NaN                       NaN
# 1          NaN      NaN                       NaN
# 2          NaN      NaN                       NaN
# 3          NaN      NaN                       NaN
# 4          NaN      NaN                       NaN
# ..         ...      ...                       ...
# 343        NaN      NaN  'vE7SCMtZPjYyRXbpKG7w4m'
# 344        NaN      NaN  'vsVbee6bQpXFhJTeQPCQht'
# 345        NaN      NaN  'vg9yF5T4pYAXDcg54xHvS6'
# 346        NaN      NaN  'v8D8TArSV88x82iVmapdGh'
# 347        NaN      NaN  'vAfX2ARcAfbFKg6Z27BKbJ'
#
# [348 rows x 13 columns]

# %%
old_form_df2 = pd.read_excel('aHuaFu4bdnJ36vR8TYet8x.xlsx', sheet_name='choices')
old_form_df2
# Out:
#      list_name   name label::Nepali (ne) label::English (en)  Province  \
# 0     Province      1           प्रदेश १        Province One       NaN
# 1     Province      2           प्रदेश २        Province Two       NaN
# 2     Province      3      बागमती प्रदेश    Bagmati Province       NaN
# 3     Province      4      गण्डकी प्रदेश    Gandaki Province       NaN
# 4     Province      5           प्रदेश ५       Province Five       NaN
# ...        ...    ...                ...                 ...       ...
# 1930   al9cj52   ___1        पुरुष सदस्य         पुरुष सदस्य       NaN
# 1931   al9cj52      _            सामुहिक             सामुहिक       NaN
# 1932   al9cj52  _3652                छैन                 छैन       NaN
# 1933   fl65i91     __           भएको छैन            भएको छैन       NaN
# 1934   fl65i91   ___1             भएको छ              भएको छ       NaN
#
#       District  order
# 0          NaN    NaN
# 1          NaN    NaN
# 2          NaN    NaN
# 3          NaN    NaN
# 4          NaN    NaN
# ...        ...    ...
# 1930       NaN    NaN
# 1931       NaN    NaN
# 1932       NaN    NaN
# 1933       NaN    NaN
# 1934       NaN    NaN
#
# [1935 rows x 7 columns]

# %%
new_form_df1 = pd.read_excel('audvtLhMwXSVHKceu8TDuD.xlsx', sheet_name='survey')
new_form_df1
# Out:
#           type                        name  \
# 0        start                       start
# 1          end                         end
# 2         note  _span_style_color_red_span
# 3         text                   Full_Name
# 4         text   Full_Name_in_Block_Letter
# ..         ...                         ...
# 339       text                       __111
# 340      image                       __112
# 341      image                       __113
# 342  calculate                 __version__
# 343  calculate                   _version_
#
#                                     label::Nepali (ne)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                             घरमुलीको ब्यक्तिगत विवरण
# 3                                             पुरा नाम
# 4                                      ब्लकमा पूरा नाम
# ..                                                 ...
# 339  ६०. करदाताको रुपमा दर्ता हुनुभएको छ भने करदाता...
# 340                                   औंठा छाप (बायाँ)
# 341                                   औंठा छाप (दायाँ)
# 342                                                NaN
# 343                                                NaN
#
#                                    label::English (en) hint::Nepali (ne)  \
# 0                                                  NaN               NaN
# 1                                                  NaN               NaN
# 2    <span style="color:red;">1. Head of the family...               NaN
# 3                                            Full Name               NaN
# 4                            Full Name in Block Letter               NaN
# ..                                                 ...               ...
# 339  ६०. करदाताको रुपमा दर्ता हुनुभएको छ भने करदाता...               NaN
# 340                                   औंठा छाप (बायाँ)               NaN
# 341                                   औंठा छाप (दायाँ)               NaN
# 342                                                NaN               NaN
# 343                                                NaN               NaN
#
#     hint::English (en) required       parameters appearance choice_filter  \
# 0                  NaN      NaN              NaN        NaN           NaN
# 1                  NaN      NaN              NaN        NaN           NaN
# 2                  NaN    False              NaN        NaN           NaN
# 3                  NaN     True              NaN        NaN           NaN
# 4                  NaN    False              NaN        NaN           NaN
# ..                 ...      ...              ...        ...           ...
# 339                NaN    False              NaN        NaN           NaN
# 340                NaN    False  max-pixels=1024        NaN           NaN
# 341                NaN    False  max-pixels=1024        NaN           NaN
# 342                NaN      NaN              NaN        NaN           NaN
# 343                NaN      NaN              NaN        NaN           NaN
#
#     constraint           relevant               calculation  $given_name
# 0          NaN                NaN                       NaN          NaN
# 1          NaN                NaN                       NaN          NaN
# 2          NaN                NaN                       NaN          NaN
# 3          NaN                NaN                       NaN          NaN
# 4          NaN                NaN                       NaN          NaN
# ..         ...                ...                       ...          ...
# 339        NaN  ${__009} = '___1'                       NaN          NaN
# 340        NaN                NaN                       NaN          NaN
# 341        NaN                NaN                       NaN          NaN
# 342        NaN                NaN  'v9C9GWtaM7FYZpk5gvtby4'          NaN
# 343        NaN                NaN  'vSTM2GySrVavtiFgT7s8Az'  __version__
#
# [344 rows x 14 columns]

# %%
new_form_df2 = pd.read_excel('audvtLhMwXSVHKceu8TDuD.xlsx', sheet_name='choices')
new_form_df2
# Out:
#      list_name           name label::Nepali (ne) label::English (en) Province  \
# 0     Province       प्रदेश १           प्रदेश १        Province One      NaN
# 1     Province       प्रदेश २           प्रदेश २        Province Two      NaN
# 2     Province  बागमती प्रदेश      बागमती प्रदेश    Bagmati Province      NaN
# 3     Province  गण्डकी प्रदेश      गण्डकी प्रदेश    Gandaki Province      NaN
# 4     Province       प्रदेश ५           प्रदेश ५       Province Five      NaN
# ...        ...            ...                ...                 ...      ...
# 1936   al9cj52    पुरुष सदस्य        पुरुष सदस्य         पुरुष सदस्य      NaN
# 1937   al9cj52        सामुहिक            सामुहिक             सामुहिक      NaN
# 1938   al9cj52            छैन                छैन                 छैन      NaN
# 1939   fl65i91       भएको छैन           भएको छैन            भएको छैन      NaN
# 1940   fl65i91         भएको छ             भएको छ              भएको छ      NaN
#
#      District  order
# 0         NaN    NaN
# 1         NaN    NaN
# 2         NaN    NaN
# 3         NaN    NaN
# 4         NaN    NaN
# ...       ...    ...
# 1936      NaN    NaN
# 1937      NaN    NaN
# 1938      NaN    NaN
# 1939      NaN    NaN
# 1940      NaN    NaN
#
# [1941 rows x 7 columns]

# %%
old_select_ones = [{'type':old_form_df1['type'][i], 'select_type': old_form_df1['type'][i].split()[0], 'sel_col_value': old_form_df1['type'][i].split()[1], 'name': old_form_df1['name'][i], 'label': old_form_df1['label::Nepali (ne)'][i]} for i in range(len(old_form_df1)) if (old_form_df1['type'][i].startswith('select_one')) | (old_form_df1['type'][i].startswith('select_multiple')) ]

# %%
old_select_ones_df = pd.DataFrame(old_select_ones)
old_select_ones_df
# Out:
#                         type select_type sel_col_value          name  \
# 0        select_one Province  select_one      Province      Province
# 1        select_one District  select_one      District  District_001
# 2    select_one Municipality  select_one  Municipality  Municipality
# 3         select_one vt1zz96  select_one       vt1zz96             _
# 4         select_one cz2jk72  select_one       cz2jk72         __001
# ..                       ...         ...           ...           ...
# 125       select_one sc2la54  select_one       sc2la54         __106
# 126       select_one ig15u66  select_one       ig15u66         __107
# 127       select_one ht9sq98  select_one       ht9sq98         __109
# 128       select_one al9cj52  select_one       al9cj52         __110
# 129       select_one fl65i91  select_one       fl65i91      _009_002
#
#                                                  label
# 0                                               प्रदेश
# 1                                               जिल्ला
# 2                                            नगरपालिका
# 3                                   घर नम्बर छ कि छैन?
# 4                  टोल विकास संस्थामा आवद्ध हो कि हैन?
# ..                                                 ...
# 125                                घरायसी काममा संलग्न
# 126                                बैँकमा खाता सञ्चालन
# 127               विद्यालय व्यवस्थापन समितिमा सहभागिता
# 128                          उद्योग व्यापारमा सहभागिता
# 129  ५९. तपाई पालिकामा करदाताको रुपमा दर्ता हुनुभएक...
#
# [130 rows x 5 columns]

# %%
new_select_ones = [{'type':new_form_df1['type'][i], 'select_type': new_form_df1['type'][i].split()[0], 'sel_col_value': new_form_df1['type'][i].split()[1], 'name': new_form_df1['name'][i]} for i in range(len(new_form_df1)) if new_form_df1['type'][i].startswith('select_one')]

# %%
new_select_ones_df = pd.DataFrame(new_select_ones)
new_select_ones_df
# Out:
#                         type select_type sel_col_value          name
# 0        select_one Province  select_one      Province      Province
# 1        select_one District  select_one      District  District_001
# 2    select_one Municipality  select_one  Municipality  Municipality
# 3         select_one vt1zz96  select_one       vt1zz96             _
# 4         select_one cz2jk72  select_one       cz2jk72         __001
# ..                       ...         ...           ...           ...
# 118       select_one sc2la54  select_one       sc2la54         __106
# 119       select_one ig15u66  select_one       ig15u66         __107
# 120       select_one ht9sq98  select_one       ht9sq98         __109
# 121       select_one al9cj52  select_one       al9cj52         __110
# 122       select_one fl65i91  select_one       fl65i91      _009_002
#
# [123 rows x 4 columns]

# %%
new_select_ones_df.columns
# Out:
# Index(['type', 'select_type', 'sel_col_value', 'name'], dtype='object')

# %%
form_value_table = []
for i in range(len(old_select_ones_df)):
    col_value = old_select_ones_df['sel_col_value'][i]
    col_choices_df = old_form_df2[old_form_df2['list_name'] == col_value]
    for j in col_choices_df.index:
        form_value_table.append({
            'type': old_select_ones_df["type"][i],
            'select_type': old_select_ones_df["select_type"][i],
            'list_name': old_select_ones_df["sel_col_value"][i],
            'name': old_select_ones_df["name"][i],
            'label': old_select_ones_df["label"][i],
            'choices_old_name': old_form_df2["name"][j],
            'choices_new_name': old_form_df2["label::Nepali (ne)"][j],
        })

# %%
form_value_table = pd.DataFrame(form_value_table)
form_value_table
# Out:
#                      type select_type list_name      name  \
# 0     select_one Province  select_one  Province  Province
# 1     select_one Province  select_one  Province  Province
# 2     select_one Province  select_one  Province  Province
# 3     select_one Province  select_one  Province  Province
# 4     select_one Province  select_one  Province  Province
# ...                   ...         ...       ...       ...
# 2136   select_one al9cj52  select_one   al9cj52     __110
# 2137   select_one al9cj52  select_one   al9cj52     __110
# 2138   select_one al9cj52  select_one   al9cj52     __110
# 2139   select_one fl65i91  select_one   fl65i91  _009_002
# 2140   select_one fl65i91  select_one   fl65i91  _009_002
#
#                                                   label choices_old_name  \
# 0                                                प्रदेश                1
# 1                                                प्रदेश                2
# 2                                                प्रदेश                3
# 3                                                प्रदेश                4
# 4                                                प्रदेश                5
# ...                                                 ...              ...
# 2136                          उद्योग व्यापारमा सहभागिता             ___1
# 2137                          उद्योग व्यापारमा सहभागिता                _
# 2138                          उद्योग व्यापारमा सहभागिता            _3652
# 2139  ५९. तपाई पालिकामा करदाताको रुपमा दर्ता हुनुभएक...               __
# 2140  ५९. तपाई पालिकामा करदाताको रुपमा दर्ता हुनुभएक...             ___1
#
#      choices_new_name
# 0            प्रदेश १
# 1            प्रदेश २
# 2       बागमती प्रदेश
# 3       गण्डकी प्रदेश
# 4            प्रदेश ५
# ...               ...
# 2136      पुरुष सदस्य
# 2137          सामुहिक
# 2138              छैन
# 2139         भएको छैन
# 2140           भएको छ
#
# [2141 rows x 7 columns]

# %%
f = open('palata_whole_data.json')
palata_data_json = json.load(f)

# %%
palata_data = palata_data_json['results']

# %%
palata_data_df = pd.DataFrame(palata_data)
palata_data_df
# Out:
#        _id                      formhub/uuid                          start  \
# 0        3  7fc2ecea664d43909afdefd37a1f3074  2023-01-22T11:14:33.065+05:45
# 1        5  7fc2ecea664d43909afdefd37a1f3074  2023-01-22T12:28:23.760+05:45
# 2        7  7fc2ecea664d43909afdefd37a1f3074  2023-01-23T07:41:27.409+05:45
# 3        8  7fc2ecea664d43909afdefd37a1f3074  2023-01-22T13:25:41.143+05:45
# 4        9  7fc2ecea664d43909afdefd37a1f3074  2023-01-23T08:46:09.963+05:45
# ...    ...                               ...                            ...
# 2573  2906  7fc2ecea664d43909afdefd37a1f3074  2023-06-11T06:47:08.627+05:45
# 2574  2907  7fc2ecea664d43909afdefd37a1f3074  2023-06-11T07:23:08.093+05:45
# 2575  2908  7fc2ecea664d43909afdefd37a1f3074  2023-06-11T08:23:08.682+05:45
# 2576  2909  7fc2ecea664d43909afdefd37a1f3074  2023-06-11T12:22:51.889+05:45
# 2577  2910  7fc2ecea664d43909afdefd37a1f3074  2023-06-07T06:48:01.168+05:45
#
#                                 end           Full_Name  \
# 0     2023-01-22T12:40:14.650+05:45          सर्जन बि क
# 1     2023-01-22T13:41:40.404+05:45            पदम बुढा
# 2     2023-01-23T08:30:15.736+05:45       जीब बहादुर बम
# 3     2023-01-22T14:40:24.775+05:45        धन बहादुर बम
# 4     2023-01-23T09:23:06.357+05:45            मदन बुढा
# ...                             ...                 ...
# 2573  2023-06-11T07:20:57.531+05:45   ज्ञान बहादुर बुढा
# 2574  2023-06-11T07:40:41.713+05:45         परेजित बुढा
# 2575  2023-06-11T08:43:17.324+05:45   रेसम्कला न्यौपाने
# 2576  2023-06-11T12:45:20.284+05:45     मनसा न्यौपाने .
# 2577  2023-06-07T07:06:39.936+05:45  बिर्ख राज न्यौपाने
#
#      Full_Name_in_Block_Letter              Photo              __006  \
# 0                   SARJAN B K  1674365422453.jpg           परि बि क
# 1                     पदम बुढा  1674369900109.jpg          नैने बुढा
# 2                जीब बहादुर बम  1674439081459.jpg      भिम बहादुर बम
# 3                 धन बहादुर बम  1674373307452.jpg  कुष्ण  बहादुर  बम
# 4                     मदन बुढा                NaN          काजि बुढा
# ...                        ...                ...                ...
# 2573               GYANA BUDHA  1686447353240.jpg         बिर्ख बुढा
# 2574             PAREJIT BUDHA  1686448535450.jpg          चैते बुढा
# 2575         RESAMKALA NEUPANE  1686452294331.jpg       दिप प्यकुरेल
# 2576            MANASA NEUPANE  1686466816337.jpg    रुपलाल न्यौपाने
# 2577        BIRKHA RAJ NEUPANE  1686100896652.jpg   बिर्जेत न्यौपाने
#
#                _006_003            __007  ... __070 _059 _065 _635 _1212 _038  \
# 0             कालि बि क     देउसिगे कामि  ...   NaN  NaN  NaN  NaN   NaN  NaN
# 1             झिमु बुढा     प्रदिपे बुढा  ...   NaN  NaN  NaN  NaN   NaN  NaN
# 2           सुबिस्ता बम     दल बहादुर बम  ...   NaN  NaN  NaN  NaN   NaN  NaN
# 3             पाटकला बम     कण बहादुर बम  ...   NaN  NaN  NaN  NaN   NaN  NaN
# 4           पाटकला बुढा    पर्दिपे बुढा   ...   NaN  NaN  NaN  NaN   NaN  NaN
# ...                 ...              ...  ...   ...  ...  ...  ...   ...  ...
# 2573         मैना  बुढा       जयलाल बुढा  ...   NaN  NaN  NaN  NaN   NaN  NaN
# 2574        बन्कला बुढा              NaN  ...   NaN  NaN  NaN  NaN   NaN  NaN
# 2575     रत्ना प्यकुरेल              NaN  ...   NaN  NaN  NaN  NaN   NaN  NaN
# 2576  सुन्तला  न्यौपाने   जयलाल न्यौपाने  ...   NaN  NaN  NaN  NaN   NaN  NaN
# 2577      छैता न्यौपाने  सुवाने न्यौपाने  ...   NaN  NaN  NaN  NaN   NaN  NaN
#
#      __080 __009 __082 __087
# 0      NaN   NaN   NaN   NaN
# 1      NaN   NaN   NaN   NaN
# 2      NaN   NaN   NaN   NaN
# 3      NaN   NaN   NaN   NaN
# 4      NaN   NaN   NaN   NaN
# ...    ...   ...   ...   ...
# 2573   NaN   NaN   NaN   NaN
# 2574   NaN   NaN   NaN   NaN
# 2575   NaN   NaN   NaN   NaN
# 2576   NaN   NaN   NaN   NaN
# 2577   NaN   NaN   NaN   NaN
#
# [2578 rows x 179 columns]

# %%
# groups_column = []
# for col in palata_data_df.columns:
#     if (col.startswith('group')) & (len(col.split('/')) == 1):
#         groups_column.append(col)
# print(groups_column)

# %%
# palata_data_df['group_th4ik74'][0]

# %%
for i in range(len(palata_data_df)):
    for col in palata_data_df.columns:
        if (col.startswith('group')) & (len(col.split('/')) == 1):
            if type(palata_data_df[col][i]) == list:
                for j in range(len(palata_data_df[col][i])):
                    for k, v in palata_data_df[col][i][j].items():
                        key = k.split('/')[-1]
                        form_masking = form_value_table[form_value_table['name'] == key]
                        if len(form_masking) != 0:
                            if form_masking['select_type'][form_masking.index[0]] == 'select_multiple':
                                multi_choices = []
                                value = v if v is not np.nan else ''
                                for val in value.split():
                                    final_row = form_masking[form_masking['choices_old_name'] == val]
                                    multi_choices.append(final_row['choices_new_name'][final_row.index[0]])
                                final_text = ' '.join(multi_choices)
                                palata_data_df[col][i][j][k] = final_text
                                
                            else:
                                final_row = form_masking[form_masking['choices_old_name'] == v]
                                try:
                                    palata_data_df[col][i][j][k] = final_row['choices_new_name'][final_row.index[0]]
                                except:
                                    pass
        else:
            key = col.split('/')
            value = palata_data_df[col][i]
            if value is not np.nan:
                form_masking = form_value_table[form_value_table['name'] == key[-1]]
                if len(form_masking) != 0:
                    if form_masking['select_type'][form_masking.index[0]] == 'select_multiple':
                        multi_choices = []
                        for val in value.split():
                            final_row = form_masking[form_masking['choices_old_name'] == val]
                            multi_choices.append(final_row['choices_new_name'][final_row.index[0]])
                        final_text = ' '.join(multi_choices)
                        palata_data_df[col][i] = final_text
                    else:
                        final_row = form_masking[form_masking['choices_old_name'] == value]
                        try:
                            palata_data_df[col][i] = final_row['choices_new_name'][final_row.index[0]]
                        except:
                            pass
# Out:
# /tmp/ipykernel_19773/1349709257.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   palata_data_df[col][i] = final_row['choices_new_name'][final_row.index[0]]
# /tmp/ipykernel_19773/1349709257.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   palata_data_df[col][i] = final_text

# %%
# palata_data_df['group_th4ik74'][0]

# %%
palata_data_df
# Out:
#        _id                      formhub/uuid                          start  \
# 0        3  7fc2ecea664d43909afdefd37a1f3074  2023-01-22T11:14:33.065+05:45
# 1        5  7fc2ecea664d43909afdefd37a1f3074  2023-01-22T12:28:23.760+05:45
# 2        7  7fc2ecea664d43909afdefd37a1f3074  2023-01-23T07:41:27.409+05:45
# 3        8  7fc2ecea664d43909afdefd37a1f3074  2023-01-22T13:25:41.143+05:45
# 4        9  7fc2ecea664d43909afdefd37a1f3074  2023-01-23T08:46:09.963+05:45
# ...    ...                               ...                            ...
# 2573  2906  7fc2ecea664d43909afdefd37a1f3074  2023-06-11T06:47:08.627+05:45
# 2574  2907  7fc2ecea664d43909afdefd37a1f3074  2023-06-11T07:23:08.093+05:45
# 2575  2908  7fc2ecea664d43909afdefd37a1f3074  2023-06-11T08:23:08.682+05:45
# 2576  2909  7fc2ecea664d43909afdefd37a1f3074  2023-06-11T12:22:51.889+05:45
# 2577  2910  7fc2ecea664d43909afdefd37a1f3074  2023-06-07T06:48:01.168+05:45
#
#                                 end           Full_Name  \
# 0     2023-01-22T12:40:14.650+05:45          सर्जन बि क
# 1     2023-01-22T13:41:40.404+05:45            पदम बुढा
# 2     2023-01-23T08:30:15.736+05:45       जीब बहादुर बम
# 3     2023-01-22T14:40:24.775+05:45        धन बहादुर बम
# 4     2023-01-23T09:23:06.357+05:45            मदन बुढा
# ...                             ...                 ...
# 2573  2023-06-11T07:20:57.531+05:45   ज्ञान बहादुर बुढा
# 2574  2023-06-11T07:40:41.713+05:45         परेजित बुढा
# 2575  2023-06-11T08:43:17.324+05:45   रेसम्कला न्यौपाने
# 2576  2023-06-11T12:45:20.284+05:45     मनसा न्यौपाने .
# 2577  2023-06-07T07:06:39.936+05:45  बिर्ख राज न्यौपाने
#
#      Full_Name_in_Block_Letter              Photo              __006  \
# 0                   SARJAN B K  1674365422453.jpg           परि बि क
# 1                     पदम बुढा  1674369900109.jpg          नैने बुढा
# 2                जीब बहादुर बम  1674439081459.jpg      भिम बहादुर बम
# 3                 धन बहादुर बम  1674373307452.jpg  कुष्ण  बहादुर  बम
# 4                     मदन बुढा                NaN          काजि बुढा
# ...                        ...                ...                ...
# 2573               GYANA BUDHA  1686447353240.jpg         बिर्ख बुढा
# 2574             PAREJIT BUDHA  1686448535450.jpg          चैते बुढा
# 2575         RESAMKALA NEUPANE  1686452294331.jpg       दिप प्यकुरेल
# 2576            MANASA NEUPANE  1686466816337.jpg    रुपलाल न्यौपाने
# 2577        BIRKHA RAJ NEUPANE  1686100896652.jpg   बिर्जेत न्यौपाने
#
#                _006_003            __007  ... __070 _059 _065 _635 _1212 _038  \
# 0             कालि बि क     देउसिगे कामि  ...   NaN  NaN  NaN  NaN   NaN  NaN
# 1             झिमु बुढा     प्रदिपे बुढा  ...   NaN  NaN  NaN  NaN   NaN  NaN
# 2           सुबिस्ता बम     दल बहादुर बम  ...   NaN  NaN  NaN  NaN   NaN  NaN
# 3             पाटकला बम     कण बहादुर बम  ...   NaN  NaN  NaN  NaN   NaN  NaN
# 4           पाटकला बुढा    पर्दिपे बुढा   ...   NaN  NaN  NaN  NaN   NaN  NaN
# ...                 ...              ...  ...   ...  ...  ...  ...   ...  ...
# 2573         मैना  बुढा       जयलाल बुढा  ...   NaN  NaN  NaN  NaN   NaN  NaN
# 2574        बन्कला बुढा              NaN  ...   NaN  NaN  NaN  NaN   NaN  NaN
# 2575     रत्ना प्यकुरेल              NaN  ...   NaN  NaN  NaN  NaN   NaN  NaN
# 2576  सुन्तला  न्यौपाने   जयलाल न्यौपाने  ...   NaN  NaN  NaN  NaN   NaN  NaN
# 2577      छैता न्यौपाने  सुवाने न्यौपाने  ...   NaN  NaN  NaN  NaN   NaN  NaN
#
#      __080 __009 __082 __087
# 0      NaN   NaN   NaN   NaN
# 1      NaN   NaN   NaN   NaN
# 2      NaN   NaN   NaN   NaN
# 3      NaN   NaN   NaN   NaN
# 4      NaN   NaN   NaN   NaN
# ...    ...   ...   ...   ...
# 2573   NaN   NaN   NaN   NaN
# 2574   NaN   NaN   NaN   NaN
# 2575   NaN   NaN   NaN   NaN
# 2576   NaN   NaN   NaN   NaN
# 2577   NaN   NaN   NaN   NaN
#
# [2578 rows x 179 columns]

# %%
improved_palata_data_df = palata_data_df.drop(['_id', '_geolocation', '_tags', '_notes'], axis=1)
improved_palata_data_df
# Out:
#                           formhub/uuid                          start  \
# 0     7fc2ecea664d43909afdefd37a1f3074  2023-01-22T11:14:33.065+05:45
# 1     7fc2ecea664d43909afdefd37a1f3074  2023-01-22T12:28:23.760+05:45
# 2     7fc2ecea664d43909afdefd37a1f3074  2023-01-23T07:41:27.409+05:45
# 3     7fc2ecea664d43909afdefd37a1f3074  2023-01-22T13:25:41.143+05:45
# 4     7fc2ecea664d43909afdefd37a1f3074  2023-01-23T08:46:09.963+05:45
# ...                                ...                            ...
# 2573  7fc2ecea664d43909afdefd37a1f3074  2023-06-11T06:47:08.627+05:45
# 2574  7fc2ecea664d43909afdefd37a1f3074  2023-06-11T07:23:08.093+05:45
# 2575  7fc2ecea664d43909afdefd37a1f3074  2023-06-11T08:23:08.682+05:45
# 2576  7fc2ecea664d43909afdefd37a1f3074  2023-06-11T12:22:51.889+05:45
# 2577  7fc2ecea664d43909afdefd37a1f3074  2023-06-07T06:48:01.168+05:45
#
#                                 end           Full_Name  \
# 0     2023-01-22T12:40:14.650+05:45          सर्जन बि क
# 1     2023-01-22T13:41:40.404+05:45            पदम बुढा
# 2     2023-01-23T08:30:15.736+05:45       जीब बहादुर बम
# 3     2023-01-22T14:40:24.775+05:45        धन बहादुर बम
# 4     2023-01-23T09:23:06.357+05:45            मदन बुढा
# ...                             ...                 ...
# 2573  2023-06-11T07:20:57.531+05:45   ज्ञान बहादुर बुढा
# 2574  2023-06-11T07:40:41.713+05:45         परेजित बुढा
# 2575  2023-06-11T08:43:17.324+05:45   रेसम्कला न्यौपाने
# 2576  2023-06-11T12:45:20.284+05:45     मनसा न्यौपाने .
# 2577  2023-06-07T07:06:39.936+05:45  बिर्ख राज न्यौपाने
#
#      Full_Name_in_Block_Letter              Photo              __006  \
# 0                   SARJAN B K  1674365422453.jpg           परि बि क
# 1                     पदम बुढा  1674369900109.jpg          नैने बुढा
# 2                जीब बहादुर बम  1674439081459.jpg      भिम बहादुर बम
# 3                 धन बहादुर बम  1674373307452.jpg  कुष्ण  बहादुर  बम
# 4                     मदन बुढा                NaN          काजि बुढा
# ...                        ...                ...                ...
# 2573               GYANA BUDHA  1686447353240.jpg         बिर्ख बुढा
# 2574             PAREJIT BUDHA  1686448535450.jpg          चैते बुढा
# 2575         RESAMKALA NEUPANE  1686452294331.jpg       दिप प्यकुरेल
# 2576            MANASA NEUPANE  1686466816337.jpg    रुपलाल न्यौपाने
# 2577        BIRKHA RAJ NEUPANE  1686100896652.jpg   बिर्जेत न्यौपाने
#
#                _006_003            __007             __008  ... __070 _059  \
# 0             कालि बि क     देउसिगे कामि        रिललि कामि  ...   NaN  NaN
# 1             झिमु बुढा     प्रदिपे बुढा         काली बुढा  ...   NaN  NaN
# 2           सुबिस्ता बम     दल बहादुर बम        बेलपुरा बम  ...   NaN  NaN
# 3             पाटकला बम     कण बहादुर बम          सरिना बम  ...   NaN  NaN
# 4           पाटकला बुढा    पर्दिपे बुढा        लालकला बुढा  ...   NaN  NaN
# ...                 ...              ...               ...  ...   ...  ...
# 2573         मैना  बुढा       जयलाल बुढा     दन्त कला बुढा  ...   NaN  NaN
# 2574        बन्कला बुढा              NaN               NaN  ...   NaN  NaN
# 2575     रत्ना प्यकुरेल              NaN               NaN  ...   NaN  NaN
# 2576  सुन्तला  न्यौपाने   जयलाल न्यौपाने    जदेनी न्यौपाने  ...   NaN  NaN
# 2577      छैता न्यौपाने  सुवाने न्यौपाने  ईन्दसरा न्यौपाने  ...   NaN  NaN
#
#      _065 _635 _1212 _038 __080 __009 __082 __087
# 0     NaN  NaN   NaN  NaN   NaN   NaN   NaN   NaN
# 1     NaN  NaN   NaN  NaN   NaN   NaN   NaN   NaN
# 2     NaN  NaN   NaN  NaN   NaN   NaN   NaN   NaN
# 3     NaN  NaN   NaN  NaN   NaN   NaN   NaN   NaN
# 4     NaN  NaN   NaN  NaN   NaN   NaN   NaN   NaN
# ...   ...  ...   ...  ...   ...   ...   ...   ...
# 2573  NaN  NaN   NaN  NaN   NaN   NaN   NaN   NaN
# 2574  NaN  NaN   NaN  NaN   NaN   NaN   NaN   NaN
# 2575  NaN  NaN   NaN  NaN   NaN   NaN   NaN   NaN
# 2576  NaN  NaN   NaN  NaN   NaN   NaN   NaN   NaN
# 2577  NaN  NaN   NaN  NaN   NaN   NaN   NaN   NaN
#
# [2578 rows x 175 columns]

# %% [markdown]
# Uncomment to export the data into json file

# %%
# palata_data_df.to_json('palata_improved_data.json', orient='records', indent=4)

# %% [markdown]
# # Starting Form Filling

# %%
TOKEN = '77d7d9c178e92e4abbb88793f6de7ca9eeef2b68'

# %%
KC_URL = 'http://kobocat.qbitsx.com'
KF_URL = 'http://koboform.qbitsx.com'

# ASSET_UID = 'aTYi4QmnpvzWcoRWzkLJ8q'
ASSET_UID = 'aYggxbvE26ZHqdBMLdxcER'

DATA_URL = f'{KF_URL}/api/v2/assets/{ASSET_UID}/data'
XML_URL = f'{DATA_URL}.xml'
SUMISSION_URL = f'{KC_URL}/api/v1/submissions'

HEADERS = {
    'Authorization': f'Token {TOKEN}'
}
PARAMS = {
    'format': 'json',
}

# %%
# Get the template from form network payload
xml_tmp = """<aYggxbvE26ZHqdBMLdxcER xmlns:jr="http://openrosa.org/javarosa" xmlns:odk="http://www.opendatakit.org/xforms" xmlns:orx="http://openrosa.org/xforms" id="aYggxbvE26ZHqdBMLdxcER" version="vuLpWNFaNCGtpGTSu28wDs">
          <formhub>
            <uuid>d6dab6a61eb34d2baaaf1d404d7805bc</uuid>
          </formhub>
          <start></start>
          <end></end>
          <_span_style_color_red_span/>
          <Full_Name></Full_Name>
          <Full_Name_in_Block_Letter></Full_Name_in_Block_Letter>
          <Photo></Photo>
          <__006></__006>
          <_006_003></_006_003>
          <__007></__007>
          <__008></__008>
          <_span_style_color_red_span_001/>
          <Province></Province>
          <District_001></District_001>
          <Municipality></Municipality>
          <__114></__114>
          <_></_>
          <__009/>
          <GPS_Location></GPS_Location>
          <__001/>
          <_span_style_color_red_span_002/>
          <__002/>
          <_span_style_color_red_span_003/>
          <__003></__003>
          <group_th4ik74>
            <_firstname></_firstname>
            <__010></__010>
            <__014></__014>
            <Full_Name_in_Block_Letter_001></Full_Name_in_Block_Letter_001>
            <__015></__015>
            <Relationship_with_the_head></Relationship_with_the_head>
            <Birth_date_year></Birth_date_year>
            <__016></__016>
            <__004/>
            <_mobilenumber></_mobilenumber>
            <__021></__021>
            <caste></caste>
            <Religion></Religion>
            <Mother_Tongue/>
            <group_rq1lx32>
              <__022/>
            </group_rq1lx32>
            <_001></_001>
            <group_af6qu72>
            </group_af6qu72>
            <_005></_005>
            <_007></_007>
            <group_qt87p58>
              <__047></__047>
              <__048></__048>
              <__049/>
            </group_qt87p58>
            <__051></__051>
            <__058></__058>
            <_008></_008>
            <__065/>
            <__066/>
            <__067></__067>
          </group_th4ik74>
          <_022_001></_022_001>
          <group_ge9ry75>
            <_002_001></_002_001>
            <_003_001></_003_001>
            <_004/>
            <_005_001></_005_001>
            <_006_001/>
            <_009_001/>
          </group_ge9ry75>
          <_023></_023>
          <_024></_024>
          <_025></_025>
          <_026></_026>
          <_029></_029>
          <_011_001/>
          <_012_001/>
          <_013></_013>
          <__068></__068>
          <group_ly7oc02>
            <_014></_014>
          </group_ly7oc02>
          <_015></_015>
          <_span_style_color_red_span_004/>
          <group_uj5xx40>
            <_016/>
            <_017></_017>
            <_018></_018>
            <_019></_019>
            <_020></_020>
            <_021></_021>
            <_030/>
            <_031></_031>
            <_032></_032>
            <_033></_033>
            <_034></_034>
            <_035></_035>
          </group_uj5xx40>
          <_001_001></_001_001>
          <_037></_037>
          <group_it9xw90>
            <_039/>
            <_040></_040>
            <_041></_041>
            <_042></_042>
            <_043></_043>
            <_043_002></_043_002>
            <_045></_045>
            <_046/>
            <_047></_047>
            <Floor_Area_Ratio></Floor_Area_Ratio>
          </group_it9xw90>
          <group_tz3jl07>
            <_10></_10>
          </group_tz3jl07>
          <_222></_222>
          <_001_002/>
          <_002_002></_002_002>
          <_635/>
          <_003_002/>
          <_004_001/>
          <__005></__005>
          <_125937></_125937>
          <_03254></_03254>
          <_4578453123123></_4578453123123>
          <__013></__013>
          <group_mz42f71>
            <_014512></_014512>
            <_12454545></_12454545>
            <_52012></_52012>
            <_12054></_12054>
            <_2155878></_2155878>
            <_212544></_212544>
            <_545121></_545121>
            <_45456876754></_45456876754>
          </group_mz42f71>
          <_version>vA4mHSLfNc8sXR4SFHtkL2</_version>
          <_span_style_color_red_span_005/>
          <_020_001></_020_001>
          <_021_001></_021_001>
          <_022_002></_022_002>
          <_023_001></_023_001>
          <_024_001></_024_001>
          <_025_001></_025_001>
          <_026_001></_026_001>
          <_027_001></_027_001>
          <group_bg5mz43>
            <_028_001></_028_001>
            <_029_001></_029_001>
          </group_bg5mz43>
          <group_hz7un93>
            <_030_001></_030_001>
            <_031_001></_031_001>
          </group_hz7un93>
          <group_ia4id04>
            <_032_001></_032_001>
            <_033_001></_033_001>
            <_034_001></_034_001>
          </group_ia4id04>
          <_035_001></_035_001>
          <__055/>
          <__057></__057>
          <_span_style_color_re_span/>
          <group_pa6pl43>
            <__069></__069>
            <_036_001></_036_001>
            <_037_001></_037_001>
          </group_pa6pl43>
          <group_qj1gh13>
            <_001_002_001/>
            <_039_001></_039_001>
          </group_qj1gh13>
          <group_gf0xy16>
            <_002_002_001/>
            <_041_001></_041_001>
          </group_gf0xy16>
          <group_xu2zb14>
            <_003_002_001></_003_002_001>
            <_042_001></_042_001>
            <_043_001></_043_001>
          </group_xu2zb14>
          <group_ea6yb02>
            <_004_001_001></_004_001_001>
            <_045_001></_045_001>
          </group_ea6yb02>
          <group_tb47x92>
            <_005_002></_005_002>
            <_046_001></_046_001>
            <_047_001></_047_001>
          </group_tb47x92>
          <group_ms8nf69>
            <_006_002></_006_002>
            <_049></_049>
          </group_ms8nf69>
          <_010_002/>
          <_span_style_color_re_span_001/>
          <_017_001></_017_001>
          <_018_001/>
          <_019_001></_019_001>
          <__087/>
          <__088/>
          <_span_style_color_re_span_002/>
          <__089></__089>
          <__090></__090>
          <__091></__091>
          <__092></__092>
          <__093></__093>
          <__094/>
          <group_wp5pw73>
            <__095></__095>
            <__096></__096>
            <__097></__097>
          </group_wp5pw73>
          <__098></__098>
          <_008_002></_008_002>
          <__100/>
          <__101/>
          <__102></__102>
          <_007_002/>
          <_span_style_color_re_span_003/>
          <__105></__105>
          <__106></__106>
          <__107></__107>
          <__109></__109>
          <__110></__110>
          <_009_002/>
          <__112></__112>
          <__113></__113>
          <__version__>v9C9GWtaM7FYZpk5gvtby4</__version__>
          <_version_>vSTM2GySrVavtiFgT7s8Az</_version_>
          <_version__001>vuLpWNFaNCGtpGTSu28wDs</_version__001>
          <meta>
            <instanceID></instanceID>
          </meta>
        </aYggxbvE26ZHqdBMLdxcER>"""

# %%
xml_template = xml_tmp.split("\n")
xml_tmplt = ''.join(xml_template)
# xml_tmplt

# %%
template = ET.fromstring(xml_tmplt)
template
# Out:
# <Element 'aYggxbvE26ZHqdBMLdxcER' at 0x7f31cf2dec00>

# %%
escape_columns = ['_id',
                  'formhub/uuid',
                  'start',
                  'end',
                  '_attachments',
                  '_version',
                  '__version__',
                  '_version_',
                  '_version__001',
                  '_version__002',
                  '_version__003',
                  '_version__004',
                  '_version__005',
                  'meta/instanceID',
                  '_xform_id_string',
                  '_uuid',
                  '_submitted_by',
                  '_validation_status',
                  '_submission_time',
                  '_status submitted_via_web',
                 ]

# %%
# ET.tostring(template).decode()

# %%
def return_formated_xml(col, val):
    col = col.split('/')
    forward = []
    backward = []
    for c in col:
        forward.append(f"<{c}>")
        backward.append(f"</{c}>")
    final_str = ''.join(forward) + val + ''.join(backward[::-1])
    return final_str

# %%
def submit_data(xml_sub: bytes, _uuid: str, file_url_list: list) -> str:
    """
    Send the XML to kobo!
    """
    file_tuple = (_uuid, io.BytesIO(xml_sub))
    files = [('xml_submission_file', file_tuple)]
    for file_url in file_url_list:
        file_name = file_url.split('/')[-1]
        files.append((file_name, open(file_url, "rb")))
    res = requests.Request(
        method='POST', url=SUMISSION_URL, files=files, headers=HEADERS
    )
    session = requests.Session()
    res = session.send(res.prepare())
    return res.status_code

def format_openrosa_datetime() -> str:
    """
    This is required to get the correct datetime formatting
    """
    return datetime.now(tz=pytz.UTC).isoformat('T', 'milliseconds')

def update_element_value(e: ET.Element, name: str, value: str) -> None:
    """
    Get or create a node and give it a value
    """
    el = e.find(name)
    if el is None:
        el = ET.SubElement(e, name)
    el.text = value

def create_submissions(data: pd.DataFrame) -> list:
    """
    Take a bunch of submissions and send them off
    """
    all_subs = []
    parsed_xml = ET.fromstring(template)
    for i, row in data.iterrows():
        _now = format_openrosa_datetime()
        _uuid = str(uuid.uuid4())
        update_element_value(parsed_xml, 'meta/instanceID', f'uuid:{_uuid}')
        
        for item in data.columns:
            update_element_value(parsed_xml, item, row[item])
        
        # We have to update the instanceID, otherwise there'll be issues
        
        # Updating the `start` and `end` times is not really necessary, but 
        # probably something you'd want to do
        update_element_value(parsed_xml, 'start', _now)
        update_element_value(parsed_xml, 'end', _now)
        
        all_subs.append(submit_data(ET.tostring(parsed_xml), _uuid))
        
        # If you are submitting a large amount of data, please be mindful that it can
        # overwhelm the servers if sent in a short span of time. Letting it sleep for
        # for a short stint between each upload will be much appreciated
        sleep(0.2)
        
    return all_subs

# %%
def post_data(data_df, index):
    parsed_xml = template
    _now = format_openrosa_datetime()
    _uuid = str(uuid.uuid4())
    for col in data_df.columns:
        if col not in escape_columns:
            column = col
            value = data_df[col][index] if data_df[col][index] is not np.nan else ''
            if value != np.nan:
                if column.startswith('group'):
                    if type(value) == list:
                        itr = 0
                        for i in value:
                            element = ET.SubElement(parsed_xml, column)
                            if itr == 0:
                                itr = 1
                                for k, v in i.items():
                                    element_find = parsed_xml.findall(k)
                                    if len(element_find) == 0:
                                        key = k.split('/')
                                        n_key = '/'.join(key[1:])
                                        format_element = return_formated_xml(n_key, v)
                                        element.append(ET.fromstring(format_element))
                                    else:
                                        update_element_value(parsed_xml, k, str(v))
                            else:
                                for k, v in i.items():
                                    key = k.split('/')
                                    n_key = '/'.join(key[1:])
                                    format_element = return_formated_xml(n_key, v)
                                    element.append(ET.fromstring(format_element))
                    else:
                        find_element = parsed_xml.find(column)
                        if find_element != None:
                            update_element_value(parsed_xml, column, str(value))
                        else:
                            format_element = return_formated_xml(column, value)
                            parsed_xml.append(ET.fromstring(format_element))
                        
                else:
                    try:
                        find_element = parsed_xml.find(column)
                        if len(find_element) != None:
                            update_element_value(parsed_xml, column, str(value))
                        else:
                            format_element = return_formated_xml(column, value)
                            parsed_xml.append(ET.fromstring(format_element))
                    except:
                        ...
    update_element_value(parsed_xml, 'meta/instanceID', f'uuid:{_uuid}')
    update_element_value(parsed_xml, 'start', _now)
    update_element_value(parsed_xml, 'end', _now)
    attachments = [i['filename'] for i in data_df['_attachments'][index]]
    all_subs = submit_data(ET.tostring(parsed_xml), _uuid, attachments)
    sleep(1)
    return all_subs

# %%
submit_status = []

# %%
for i in range(len(improved_palata_data_df)):
    if i > 1797:
        status = post_data(improved_palata_data_df, i)
        submit_status.append({'index':i, 'status_code':status})
        print({'index':i, 'status_code':status})
# Out:
# {'index': 1290, 'status_code': 201}
# {'index': 1291, 'status_code': 201}
# {'index': 1292, 'status_code': 201}
# {'index': 1293, 'status_code': 201}
# {'index': 1294, 'status_code': 201}
# {'index': 1295, 'status_code': 201}
# {'index': 1296, 'status_code': 201}
# {'index': 1297, 'status_code': 201}
# {'index': 1298, 'status_code': 201}
# {'index': 1299, 'status_code': 201}
# {'index': 1300, 'status_code': 201}
# {'index': 1301, 'status_code': 201}
# {'index': 1302, 'status_code': 201}
# {'index': 1303, 'status_code': 201}
# {'index': 1304, 'status_code': 201}
# {'index': 1305, 'status_code': 201}
# {'index': 1306, 'status_code': 201}
# {'index': 1307, 'status_code': 201}
# {'index': 1308, 'status_code': 201}
# {'index': 1309, 'status_code': 201}
# {'index': 1310, 'status_code': 201}
# {'index': 1311, 'status_code': 201}
# {'index': 1312, 'status_code': 201}
# {'index': 1313, 'status_code': 201}
# {'index': 1314, 'status_code': 201}
# {'index': 1315, 'status_code': 201}
# {'index': 1316, 'status_code': 201}
# {'index': 1317, 'status_code': 201}
# {'index': 1318, 'status_code': 201}
# {'index': 1319, 'status_code': 201}
# {'index': 1320, 'status_code': 201}
# {'index': 1321, 'status_code': 201}
# {'index': 1322, 'status_code': 201}
# {'index': 1323, 'status_code': 201}
# {'index': 1324, 'status_code': 201}
# {'index': 1325, 'status_code': 201}
# {'index': 1326, 'status_code': 201}
# {'index': 1327, 'status_code': 201}
# {'index': 1328, 'status_code': 201}
# {'index': 1329, 'status_code': 201}
# {'index': 1330, 'status_code': 201}
# {'index': 1331, 'status_code': 201}
# {'index': 1332, 'status_code': 201}
# {'index': 1333, 'status_code': 201}
# {'index': 1334, 'status_code': 201}
# {'index': 1335, 'status_code': 201}
# {'index': 1336, 'status_code': 201}
# {'index': 1337, 'status_code': 201}
# {'index': 1338, 'status_code': 201}
# {'index': 1339, 'status_code': 201}
# {'index': 1340, 'status_code': 201}
# {'index': 1341, 'status_code': 201}
# {'index': 1342, 'status_code': 201}
# {'index': 1343, 'status_code': 201}
# {'index': 1344, 'status_code': 201}
# {'index': 1345, 'status_code': 201}
# {'index': 1346, 'status_code': 201}
# {'index': 1347, 'status_code': 201}
# {'index': 1348, 'status_code': 201}
# {'index': 1349, 'status_code': 201}
# {'index': 1350, 'status_code': 201}
# {'index': 1351, 'status_code': 201}
# {'index': 1352, 'status_code': 201}
# {'index': 1353, 'status_code': 201}
# {'index': 1354, 'status_code': 201}
# {'index': 1355, 'status_code': 201}
# {'index': 1356, 'status_code': 201}
# {'index': 1357, 'status_code': 201}
# {'index': 1358, 'status_code': 201}
# {'index': 1359, 'status_code': 201}
# {'index': 1360, 'status_code': 201}
# {'index': 1361, 'status_code': 201}
# {'index': 1362, 'status_code': 201}
# {'index': 1363, 'status_code': 201}
# {'index': 1364, 'status_code': 201}
# {'index': 1365, 'status_code': 201}
# {'index': 1366, 'status_code': 201}
# {'index': 1367, 'status_code': 201}
# {'index': 1368, 'status_code': 201}
# {'index': 1369, 'status_code': 201}
# {'index': 1370, 'status_code': 201}
# {'index': 1371, 'status_code': 201}
# {'index': 1372, 'status_code': 201}
# {'index': 1373, 'status_code': 201}
# {'index': 1374, 'status_code': 201}
# {'index': 1375, 'status_code': 201}
# {'index': 1376, 'status_code': 201}
# {'index': 1377, 'status_code': 201}
# {'index': 1378, 'status_code': 201}
# {'index': 1379, 'status_code': 201}
# {'index': 1380, 'status_code': 201}
# {'index': 1381, 'status_code': 201}
# {'index': 1382, 'status_code': 201}
# {'index': 1383, 'status_code': 201}
# {'index': 1384, 'status_code': 201}
# {'index': 1385, 'status_code': 201}
# {'index': 1386, 'status_code': 201}
# {'index': 1387, 'status_code': 201}
# {'index': 1388, 'status_code': 201}
# {'index': 1389, 'status_code': 201}
# {'index': 1390, 'status_code': 201}
# {'index': 1391, 'status_code': 201}
# {'index': 1392, 'status_code': 201}
# {'index': 1393, 'status_code': 201}
# {'index': 1394, 'status_code': 201}
# {'index': 1395, 'status_code': 201}
# {'index': 1396, 'status_code': 201}
# {'index': 1397, 'status_code': 201}
# {'index': 1398, 'status_code': 201}
# {'index': 1399, 'status_code': 201}
# {'index': 1400, 'status_code': 201}
# {'index': 1401, 'status_code': 201}
# {'index': 1402, 'status_code': 201}
# {'index': 1403, 'status_code': 201}
# {'index': 1404, 'status_code': 201}
# {'index': 1405, 'status_code': 201}
# {'index': 1406, 'status_code': 201}
# {'index': 1407, 'status_code': 201}
# {'index': 1408, 'status_code': 201}
# {'index': 1409, 'status_code': 201}
# {'index': 1410, 'status_code': 201}
# {'index': 1411, 'status_code': 201}
# {'index': 1412, 'status_code': 201}
# {'index': 1413, 'status_code': 201}
# {'index': 1414, 'status_code': 201}
# {'index': 1415, 'status_code': 201}
# {'index': 1416, 'status_code': 201}
# {'index': 1417, 'status_code': 201}
# {'index': 1418, 'status_code': 201}
# {'index': 1419, 'status_code': 201}
# {'index': 1420, 'status_code': 201}
# {'index': 1421, 'status_code': 201}
# {'index': 1422, 'status_code': 201}
# {'index': 1423, 'status_code': 201}
# {'index': 1424, 'status_code': 201}
# {'index': 1425, 'status_code': 201}
# {'index': 1426, 'status_code': 201}
# {'index': 1427, 'status_code': 201}
# {'index': 1428, 'status_code': 201}
# {'index': 1429, 'status_code': 201}
# {'index': 1430, 'status_code': 201}
# {'index': 1431, 'status_code': 201}
# {'index': 1432, 'status_code': 201}
# {'index': 1433, 'status_code': 201}
# {'index': 1434, 'status_code': 201}
# {'index': 1435, 'status_code': 201}
# {'index': 1436, 'status_code': 201}
# {'index': 1437, 'status_code': 201}
# {'index': 1438, 'status_code': 201}
# {'index': 1439, 'status_code': 201}
# {'index': 1440, 'status_code': 201}
# {'index': 1441, 'status_code': 201}
# {'index': 1442, 'status_code': 201}
# {'index': 1443, 'status_code': 201}
# {'index': 1444, 'status_code': 201}
# {'index': 1445, 'status_code': 201}
# {'index': 1446, 'status_code': 201}
# {'index': 1447, 'status_code': 201}
# {'index': 1448, 'status_code': 201}
# {'index': 1449, 'status_code': 201}
# {'index': 1450, 'status_code': 201}
# {'index': 1451, 'status_code': 201}
# {'index': 1452, 'status_code': 201}
# {'index': 1453, 'status_code': 201}
# {'index': 1454, 'status_code': 201}
# {'index': 1455, 'status_code': 201}
# {'index': 1456, 'status_code': 201}
# {'index': 1457, 'status_code': 201}
# {'index': 1458, 'status_code': 201}
# {'index': 1459, 'status_code': 201}
# {'index': 1460, 'status_code': 201}
# {'index': 1461, 'status_code': 201}
# {'index': 1462, 'status_code': 201}
# {'index': 1463, 'status_code': 201}
# {'index': 1464, 'status_code': 201}
# {'index': 1465, 'status_code': 201}
# {'index': 1466, 'status_code': 201}
# {'index': 1467, 'status_code': 201}
# {'index': 1468, 'status_code': 201}
# {'index': 1469, 'status_code': 201}
# {'index': 1470, 'status_code': 201}
# {'index': 1471, 'status_code': 201}
# {'index': 1472, 'status_code': 201}
# {'index': 1473, 'status_code': 201}
# {'index': 1474, 'status_code': 201}
# {'index': 1475, 'status_code': 201}
# {'index': 1476, 'status_code': 201}
# {'index': 1477, 'status_code': 201}
# {'index': 1478, 'status_code': 201}
# {'index': 1479, 'status_code': 201}
# {'index': 1480, 'status_code': 201}
# {'index': 1481, 'status_code': 201}
# {'index': 1482, 'status_code': 201}
# {'index': 1483, 'status_code': 201}
# {'index': 1484, 'status_code': 201}
# {'index': 1485, 'status_code': 201}
# {'index': 1486, 'status_code': 201}
# {'index': 1487, 'status_code': 201}
# {'index': 1488, 'status_code': 201}
# {'index': 1489, 'status_code': 201}
# {'index': 1490, 'status_code': 201}
# {'index': 1491, 'status_code': 201}
# {'index': 1492, 'status_code': 201}
# {'index': 1493, 'status_code': 201}
# {'index': 1494, 'status_code': 201}
# {'index': 1495, 'status_code': 201}
# {'index': 1496, 'status_code': 201}
# {'index': 1497, 'status_code': 201}
# {'index': 1498, 'status_code': 201}
# {'index': 1499, 'status_code': 201}
# {'index': 1500, 'status_code': 201}
# {'index': 1501, 'status_code': 201}
# {'index': 1502, 'status_code': 201}
# {'index': 1503, 'status_code': 201}
# {'index': 1504, 'status_code': 201}
# {'index': 1505, 'status_code': 201}
# {'index': 1506, 'status_code': 201}
# {'index': 1507, 'status_code': 201}
# {'index': 1508, 'status_code': 201}
# {'index': 1509, 'status_code': 201}
# {'index': 1510, 'status_code': 201}
# {'index': 1511, 'status_code': 201}
# {'index': 1512, 'status_code': 201}
# {'index': 1513, 'status_code': 201}
# {'index': 1514, 'status_code': 201}
# {'index': 1515, 'status_code': 201}
# {'index': 1516, 'status_code': 201}
# {'index': 1517, 'status_code': 201}
# {'index': 1518, 'status_code': 201}
# {'index': 1519, 'status_code': 201}
# {'index': 1520, 'status_code': 201}
# {'index': 1521, 'status_code': 201}
# {'index': 1522, 'status_code': 201}
# {'index': 1523, 'status_code': 201}
# {'index': 1524, 'status_code': 201}
# {'index': 1525, 'status_code': 201}
# {'index': 1526, 'status_code': 201}
# {'index': 1527, 'status_code': 201}
# {'index': 1528, 'status_code': 201}
# {'index': 1529, 'status_code': 201}
# {'index': 1530, 'status_code': 201}
# {'index': 1531, 'status_code': 201}
# {'index': 1532, 'status_code': 201}
# {'index': 1533, 'status_code': 201}
# {'index': 1534, 'status_code': 201}
# {'index': 1535, 'status_code': 201}
# {'index': 1536, 'status_code': 201}
# {'index': 1537, 'status_code': 201}
# {'index': 1538, 'status_code': 201}
# {'index': 1539, 'status_code': 201}
# {'index': 1540, 'status_code': 201}
# {'index': 1541, 'status_code': 201}
# {'index': 1542, 'status_code': 201}
# {'index': 1543, 'status_code': 201}
# {'index': 1544, 'status_code': 201}
# {'index': 1545, 'status_code': 201}
# {'index': 1546, 'status_code': 201}
# {'index': 1547, 'status_code': 201}
# {'index': 1548, 'status_code': 201}
# {'index': 1549, 'status_code': 201}
# {'index': 1550, 'status_code': 201}
# {'index': 1551, 'status_code': 201}
# {'index': 1552, 'status_code': 201}
# {'index': 1553, 'status_code': 201}
# {'index': 1554, 'status_code': 201}
# {'index': 1555, 'status_code': 201}
# {'index': 1556, 'status_code': 201}
# {'index': 1557, 'status_code': 201}
# {'index': 1558, 'status_code': 201}
# {'index': 1559, 'status_code': 201}
# {'index': 1560, 'status_code': 201}
# {'index': 1561, 'status_code': 201}
# {'index': 1562, 'status_code': 201}
# {'index': 1563, 'status_code': 201}
# {'index': 1564, 'status_code': 201}
# {'index': 1565, 'status_code': 201}
# {'index': 1566, 'status_code': 201}
# {'index': 1567, 'status_code': 201}
# {'index': 1568, 'status_code': 201}
# {'index': 1569, 'status_code': 201}
# {'index': 1570, 'status_code': 201}
# {'index': 1571, 'status_code': 201}
# {'index': 1572, 'status_code': 201}
# {'index': 1573, 'status_code': 201}
# {'index': 1574, 'status_code': 201}
# {'index': 1575, 'status_code': 201}
# {'index': 1576, 'status_code': 201}
# {'index': 1577, 'status_code': 201}
# {'index': 1578, 'status_code': 201}
# {'index': 1579, 'status_code': 201}
# {'index': 1580, 'status_code': 201}
# {'index': 1581, 'status_code': 201}
# {'index': 1582, 'status_code': 201}
# {'index': 1583, 'status_code': 201}
# {'index': 1584, 'status_code': 201}
# {'index': 1585, 'status_code': 201}
# {'index': 1586, 'status_code': 201}
# {'index': 1587, 'status_code': 201}
# {'index': 1588, 'status_code': 201}
# {'index': 1589, 'status_code': 201}
# {'index': 1590, 'status_code': 201}
# {'index': 1591, 'status_code': 201}
# {'index': 1592, 'status_code': 201}
# {'index': 1593, 'status_code': 201}
# {'index': 1594, 'status_code': 201}
# {'index': 1595, 'status_code': 201}
# {'index': 1596, 'status_code': 201}
# {'index': 1597, 'status_code': 201}
# {'index': 1598, 'status_code': 201}
# {'index': 1599, 'status_code': 201}
# {'index': 1600, 'status_code': 201}
# {'index': 1601, 'status_code': 201}
# {'index': 1602, 'status_code': 201}
# {'index': 1603, 'status_code': 201}
# {'index': 1604, 'status_code': 201}
# {'index': 1605, 'status_code': 201}
# {'index': 1606, 'status_code': 201}
# {'index': 1607, 'status_code': 201}
# {'index': 1608, 'status_code': 201}
# {'index': 1609, 'status_code': 201}
# {'index': 1610, 'status_code': 201}
# {'index': 1611, 'status_code': 201}
# {'index': 1612, 'status_code': 201}
# {'index': 1613, 'status_code': 201}
# {'index': 1614, 'status_code': 201}
# {'index': 1615, 'status_code': 201}
# {'index': 1616, 'status_code': 201}
# {'index': 1617, 'status_code': 201}
# {'index': 1618, 'status_code': 201}
# {'index': 1619, 'status_code': 201}
# {'index': 1620, 'status_code': 201}
# {'index': 1621, 'status_code': 201}
# {'index': 1622, 'status_code': 201}
# {'index': 1623, 'status_code': 201}
# {'index': 1624, 'status_code': 201}
# {'index': 1625, 'status_code': 201}
# {'index': 1626, 'status_code': 201}
# {'index': 1627, 'status_code': 201}
# {'index': 1628, 'status_code': 201}
# {'index': 1629, 'status_code': 201}
# {'index': 1630, 'status_code': 201}
# {'index': 1631, 'status_code': 201}
# {'index': 1632, 'status_code': 201}
# {'index': 1633, 'status_code': 201}
# {'index': 1634, 'status_code': 201}
# {'index': 1635, 'status_code': 201}
# {'index': 1636, 'status_code': 201}
# {'index': 1637, 'status_code': 201}
# {'index': 1638, 'status_code': 201}
# {'index': 1639, 'status_code': 201}
# {'index': 1640, 'status_code': 201}
# {'index': 1641, 'status_code': 201}
# {'index': 1642, 'status_code': 201}
# {'index': 1643, 'status_code': 201}
# {'index': 1644, 'status_code': 201}
# {'index': 1645, 'status_code': 201}
# {'index': 1646, 'status_code': 201}
# {'index': 1647, 'status_code': 201}
# {'index': 1648, 'status_code': 201}
# {'index': 1649, 'status_code': 201}
# {'index': 1650, 'status_code': 201}
# {'index': 1651, 'status_code': 201}
# {'index': 1652, 'status_code': 201}
# {'index': 1653, 'status_code': 201}
# {'index': 1654, 'status_code': 201}
# {'index': 1655, 'status_code': 201}
# {'index': 1656, 'status_code': 201}
# {'index': 1657, 'status_code': 201}
# {'index': 1658, 'status_code': 201}
# {'index': 1659, 'status_code': 201}
# {'index': 1660, 'status_code': 201}
# {'index': 1661, 'status_code': 201}
# {'index': 1662, 'status_code': 201}
# {'index': 1663, 'status_code': 201}
# {'index': 1664, 'status_code': 201}
# {'index': 1665, 'status_code': 201}
# {'index': 1666, 'status_code': 201}
# {'index': 1667, 'status_code': 201}
# {'index': 1668, 'status_code': 201}
# {'index': 1669, 'status_code': 201}
# {'index': 1670, 'status_code': 201}
# {'index': 1671, 'status_code': 201}
# {'index': 1672, 'status_code': 201}
# {'index': 1673, 'status_code': 201}
# {'index': 1674, 'status_code': 201}
# {'index': 1675, 'status_code': 201}
# {'index': 1676, 'status_code': 201}
# {'index': 1677, 'status_code': 201}
# {'index': 1678, 'status_code': 201}
# {'index': 1679, 'status_code': 201}
# {'index': 1680, 'status_code': 201}
# {'index': 1681, 'status_code': 201}
# {'index': 1682, 'status_code': 201}
# {'index': 1683, 'status_code': 201}
# {'index': 1684, 'status_code': 201}
# {'index': 1685, 'status_code': 201}
# {'index': 1686, 'status_code': 201}
# {'index': 1687, 'status_code': 201}
# {'index': 1688, 'status_code': 201}
# {'index': 1689, 'status_code': 201}
# {'index': 1690, 'status_code': 201}
# {'index': 1691, 'status_code': 201}
# {'index': 1692, 'status_code': 201}
# {'index': 1693, 'status_code': 201}
# {'index': 1694, 'status_code': 201}
# {'index': 1695, 'status_code': 201}
# {'index': 1696, 'status_code': 201}
# {'index': 1697, 'status_code': 201}
# {'index': 1698, 'status_code': 201}
# {'index': 1699, 'status_code': 201}
# {'index': 1700, 'status_code': 201}
# {'index': 1701, 'status_code': 201}
# {'index': 1702, 'status_code': 201}
# {'index': 1703, 'status_code': 201}
# {'index': 1704, 'status_code': 201}
# {'index': 1705, 'status_code': 201}
# {'index': 1706, 'status_code': 201}
# {'index': 1707, 'status_code': 201}
# {'index': 1708, 'status_code': 201}
# {'index': 1709, 'status_code': 201}
# {'index': 1710, 'status_code': 201}
# {'index': 1711, 'status_code': 201}
# {'index': 1712, 'status_code': 201}
# {'index': 1713, 'status_code': 201}
# {'index': 1714, 'status_code': 201}
# {'index': 1715, 'status_code': 201}
# {'index': 1716, 'status_code': 201}
# {'index': 1717, 'status_code': 201}
# {'index': 1718, 'status_code': 201}
# {'index': 1719, 'status_code': 201}
# {'index': 1720, 'status_code': 201}
# {'index': 1721, 'status_code': 201}
# {'index': 1722, 'status_code': 201}
# {'index': 1723, 'status_code': 201}
# {'index': 1724, 'status_code': 201}
# {'index': 1725, 'status_code': 201}
# {'index': 1726, 'status_code': 201}
# {'index': 1727, 'status_code': 201}
# {'index': 1728, 'status_code': 201}
# {'index': 1729, 'status_code': 201}
# {'index': 1730, 'status_code': 201}
# {'index': 1731, 'status_code': 201}
# {'index': 1732, 'status_code': 201}
# {'index': 1733, 'status_code': 201}
# {'index': 1734, 'status_code': 201}
# {'index': 1735, 'status_code': 201}
# {'index': 1736, 'status_code': 201}
# {'index': 1737, 'status_code': 201}
# {'index': 1738, 'status_code': 201}
# {'index': 1739, 'status_code': 201}
# {'index': 1740, 'status_code': 201}
# {'index': 1741, 'status_code': 201}
# {'index': 1742, 'status_code': 201}
# {'index': 1743, 'status_code': 201}
# {'index': 1744, 'status_code': 201}
# {'index': 1745, 'status_code': 201}
# {'index': 1746, 'status_code': 201}
# {'index': 1747, 'status_code': 201}
# {'index': 1748, 'status_code': 201}
# {'index': 1749, 'status_code': 201}
# {'index': 1750, 'status_code': 201}
# {'index': 1751, 'status_code': 201}
# {'index': 1752, 'status_code': 201}
# {'index': 1753, 'status_code': 201}
# {'index': 1754, 'status_code': 201}
# {'index': 1755, 'status_code': 201}
# {'index': 1756, 'status_code': 201}
# {'index': 1757, 'status_code': 201}
# {'index': 1758, 'status_code': 201}
# {'index': 1759, 'status_code': 201}
# {'index': 1760, 'status_code': 201}
# {'index': 1761, 'status_code': 201}
# {'index': 1762, 'status_code': 201}
# {'index': 1763, 'status_code': 201}
# {'index': 1764, 'status_code': 201}
# {'index': 1765, 'status_code': 201}
# {'index': 1766, 'status_code': 201}
# {'index': 1767, 'status_code': 201}
# {'index': 1768, 'status_code': 201}
# {'index': 1769, 'status_code': 201}
# {'index': 1770, 'status_code': 201}
# {'index': 1771, 'status_code': 201}
# {'index': 1772, 'status_code': 201}
# {'index': 1773, 'status_code': 201}
# {'index': 1774, 'status_code': 201}
# {'index': 1775, 'status_code': 201}
# {'index': 1776, 'status_code': 201}
# {'index': 1777, 'status_code': 201}
# {'index': 1778, 'status_code': 201}
# {'index': 1779, 'status_code': 201}
# {'index': 1780, 'status_code': 201}
# {'index': 1781, 'status_code': 201}
# {'index': 1782, 'status_code': 201}
# {'index': 1783, 'status_code': 201}
# {'index': 1784, 'status_code': 201}
# {'index': 1785, 'status_code': 201}
# {'index': 1786, 'status_code': 201}
# {'index': 1787, 'status_code': 201}
# {'index': 1788, 'status_code': 201}
# {'index': 1789, 'status_code': 201}
# {'index': 1790, 'status_code': 201}
# {'index': 1791, 'status_code': 201}
# {'index': 1792, 'status_code': 201}
# {'index': 1793, 'status_code': 201}
# {'index': 1794, 'status_code': 201}
# {'index': 1795, 'status_code': 201}
# {'index': 1796, 'status_code': 201}
# {'index': 1797, 'status_code': 201}
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:699, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698 # Make the request on the httplib connection object.
# --> 699 httplib_response = self._make_request(
#     700     conn,
#     701     method,
#     702     url,
#     703     timeout=timeout_obj,
#     704     body=body,
#     705     headers=headers,
#     706     chunked=chunked,
#     707 )
#     709 # If we're going to release the connection in ``finally:``, then
#     710 # the response doesn't need to know about the connection. Otherwise
#     711 # it will also try to release it and we'll have a double-release
#     712 # mess.
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:394, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     393     else:
# --> 394         conn.request(method, url, **httplib_request_kw)
#     396 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     397 # legitimately able to close the connection after sending a valid response.
#     398 # With this behaviour, the received response is still readable.
#
# File /usr/lib/python3/dist-packages/urllib3/connection.py:234, in HTTPConnection.request(self, method, url, body, headers)
#     233     headers["User-Agent"] = _get_default_user_agent()
# --> 234 super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#
# File /usr/lib/python3.10/http/client.py:1282, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1281 """Send a complete request to the server."""
# -> 1282 self._send_request(method, url, body, headers, encode_chunked)
#
# File /usr/lib/python3.10/http/client.py:1328, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1327     body = _encode(body, 'body')
# -> 1328 self.endheaders(body, encode_chunked=encode_chunked)
#
# File /usr/lib/python3.10/http/client.py:1277, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1276     raise CannotSendHeader()
# -> 1277 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /usr/lib/python3.10/http/client.py:1076, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1074         chunk = f'{len(chunk):X}\r\n'.encode('ascii') + chunk \
#    1075             + b'\r\n'
# -> 1076     self.send(chunk)
#    1078 if encode_chunked and self._http_vsn == 11:
#    1079     # end chunked transfer
#
# File /usr/lib/python3.10/http/client.py:998, in HTTPConnection.send(self, data)
#     997 try:
# --> 998     self.sock.sendall(data)
#     999 except TypeError:
#
# OSError: [Errno 101] Network is unreachable
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:755, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     753     e = ProtocolError("Connection aborted.", e)
# --> 755 retries = retries.increment(
#     756     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     757 )
#     758 retries.sleep()
#
# File /usr/lib/python3/dist-packages/urllib3/util/retry.py:532, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     531 if read is False or not self._is_method_retryable(method):
# --> 532     raise six.reraise(type(error), error, _stacktrace)
#     533 elif read is not None:
#
# File ~/.local/lib/python3.10/site-packages/six.py:718, in reraise(tp, value, tb)
#     717 if value.__traceback__ is not tb:
# --> 718     raise value.with_traceback(tb)
#     719 raise value
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:699, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698 # Make the request on the httplib connection object.
# --> 699 httplib_response = self._make_request(
#     700     conn,
#     701     method,
#     702     url,
#     703     timeout=timeout_obj,
#     704     body=body,
#     705     headers=headers,
#     706     chunked=chunked,
#     707 )
#     709 # If we're going to release the connection in ``finally:``, then
#     710 # the response doesn't need to know about the connection. Otherwise
#     711 # it will also try to release it and we'll have a double-release
#     712 # mess.
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:394, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     393     else:
# --> 394         conn.request(method, url, **httplib_request_kw)
#     396 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     397 # legitimately able to close the connection after sending a valid response.
#     398 # With this behaviour, the received response is still readable.
#
# File /usr/lib/python3/dist-packages/urllib3/connection.py:234, in HTTPConnection.request(self, method, url, body, headers)
#     233     headers["User-Agent"] = _get_default_user_agent()
# --> 234 super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#
# File /usr/lib/python3.10/http/client.py:1282, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1281 """Send a complete request to the server."""
# -> 1282 self._send_request(method, url, body, headers, encode_chunked)
#
# File /usr/lib/python3.10/http/client.py:1328, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1327     body = _encode(body, 'body')
# -> 1328 self.endheaders(body, encode_chunked=encode_chunked)
#
# File /usr/lib/python3.10/http/client.py:1277, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1276     raise CannotSendHeader()
# -> 1277 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /usr/lib/python3.10/http/client.py:1076, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1074         chunk = f'{len(chunk):X}\r\n'.encode('ascii') + chunk \
#    1075             + b'\r\n'
# -> 1076     self.send(chunk)
#    1078 if encode_chunked and self._http_vsn == 11:
#    1079     # end chunked transfer
#
# File /usr/lib/python3.10/http/client.py:998, in HTTPConnection.send(self, data)
#     997 try:
# --> 998     self.sock.sendall(data)
#     999 except TypeError:
#
# ProtocolError: ('Connection aborted.', OSError(101, 'Network is unreachable'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Input In [48], in <cell line: 1>()
#       1 for i in range(len(improved_palata_data_df)):
#       2     if i > 1289:
# ----> 3         status = post_data(improved_palata_data_df, i)
#       4         submit_status.append({'index':i, 'status_code':status})
#       5         print({'index':i, 'status_code':status})
#
# Input In [46], in post_data(data_df, index)
#      52 update_element_value(parsed_xml, 'end', _now)
#      53 attachments = [i['filename'] for i in data_df['_attachments'][index]]
# ---> 54 all_subs = submit_data(ET.tostring(parsed_xml), _uuid, attachments)
#      55 sleep(1)
#      56 return all_subs
#
# Input In [45], in submit_data(xml_sub, _uuid, file_url_list)
#      10 res = requests.Request(
#      11     method='POST', url=SUMISSION_URL, files=files, headers=HEADERS
#      12 )
#      13 session = requests.Session()
# ---> 14 res = session.send(res.prepare())
#      15 return res.status_code
#
# File ~/.local/lib/python3.10/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/.local/lib/python3.10/site-packages/requests/adapters.py:547, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     544             raise
#     546 except (ProtocolError, OSError) as err:
# --> 547     raise ConnectionError(err, request=request)
#     549 except MaxRetryError as e:
#     550     if isinstance(e.reason, ConnectTimeoutError):
#     551         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', OSError(101, 'Network is unreachable'))

# %%
submit_status_df = pd.DataFrame(submit_status)
submit_status_df
# Out:
#      index  status_code
# 0     1290          201
# 1     1291          201
# 2     1292          201
# 3     1293          201
# 4     1294          201
# ..     ...          ...
# 503   1793          201
# 504   1794          201
# 505   1795          201
# 506   1796          201
# 507   1797          201
#
# [508 rows x 2 columns]

# %%
# submit_status_df.to_csv('status1.csv')
